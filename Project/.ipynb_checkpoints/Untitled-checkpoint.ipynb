# %%
from scipy import constants as const
import numpy as np
import matplotlib.pyplot as plt

# %%
# constants
e = const.e
hbar = const.hbar
eps_0 = const.epsilon_0
m_e = const.m_e
pi = const.pi
a = 4 * pi * eps_0 * hbar**2 / m_e / e**2
print(a)

# define the potential
def V(r, l):
    alpha = e**2 / (4 * pi * eps_0)
    beta = (hbar**2 / 2 / m_e) * l * (l+1)
    return -alpha / r + beta / r**2
# Out:
# 5.291772105443463e-11

# %%
# quantum numbers
n = 1
l = 0

# discretize the r-grid
r_i = 0
r_f = 25*a
n = 101
dx = (r_f-r_i) / (n-1)
k = hbar**2 / (2 * m_e * dx**2)
print(k)

r = np.linspace(r_i,r_f,n)

# build the hamiltonian matrix
H = np.zeros((n-2,n-2))

H[0][0] = 2*k + V(r[1],l)
H[0][1] = -k

H[-1][-2]= -k
H[-1][-1]= 2*k + V(r[n-2],l)

for ii in range(1,n-3):
    H[ii][ii] = 2*k + V(r[ii+1],l)
    H[ii][ii+1] = -k
    H[ii][ii-1] = -k

print(H)
# Out:
# 3.487795777758673e-17
# [[ 5.23169367e-17 -3.48779578e-17  0.00000000e+00 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-3.48779578e-17  6.10364261e-17 -3.48779578e-17 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -3.48779578e-17  6.39429226e-17 ...  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  ...
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  6.95761323e-17
#   -3.48779578e-17  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ... -3.48779578e-17
#    6.95779668e-17 -3.48779578e-17]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#   -3.48779578e-17  6.95797643e-17]]

# %%
energies, solns = np.linalg.eigh(H)
print('First Three Energies: ', energies[0:3]/e)
# Out:
# First Three Energies:  [-13.39949891  -3.38823249  -1.48262954]
