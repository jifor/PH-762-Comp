# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 4 * np.pi # m

def R_10(r):
    a = 4 * np.pi # m
    return 2 * a**(-3/2) * np.exp(-r/a)

r = np.linspace(0.1,300,10001)
r_multiples = r / a
plt.plot(r_multiples, R_10(r))

# %%
def E(n):
    return -1 / (32 * np.pi**2 * n**2)

def f(v, r, E, l):
    u = v[0]
    w = v[1]

    K = (l*(l-1)/r**2) - 2*E - 1/(2*np.pi*r)

    fu = w
    fw = K * u

    return np.array([fu,fw])

print(E(1), E(2))
# Out:
# -0.0031662869888230555 -0.0007915717472057639

# %%
# quantum numbers
principle = 1
l = 0

r_i = 0.0001
r_f = 300
n = 100001
h = (r_f - r_i) / (n - 1)

r = np.linspace(r_i,r_f,n)

u = np.zeros(n)
w = np.zeros(n)
u[0]=0
w[0]=1e-5

v = np.array([u[0],w[0]])

for i in range(n-1):
    k1 = f(v,r[i],principle,l)
    k2 = f(v+k1*h/2, r[i]+h/2,principle,l)
    k3 = f(v+k2*h/2, r[i]+h/2,principle,l)
    k4 = f(v+k3*h, r[i]+h,principle,l)

    v = v + h*(k1+2*k2+2*k3+k4)/6

    u[i+1] = v[0]
    w[i+1] = v[1]

radial = u/r
plt.plot(r,radial)
plt.axhline(y=0)

# %%
def RK4(E,l):
    r_i = 0.0001
    r_f = 300
    n = 1001
    h = (r_f - r_i) / (n - 1)
    
    r = np.linspace(r_i,r_f,n)

    u = np.zeros(n)
    w = np.zeros(n)
    u[0]=0
    w[0]=1e-5
    
    v = np.array([u[0],w[0]])
    
    for i in range(n-1):
        k1 = f(v,r[i],E,l)
        k2 = f(v+k1*h/2, r[i]+h/2,E,l)
        k3 = f(v+k2*h/2, r[i]+h/2,E,l)
        k4 = f(v+k3*h, r[i]+h,E,l)
    
        v = v + h*(k1+2*k2+2*k3+k4)/6
    
        u[i+1] = v[0]
        w[i+1] = v[1]

    return r, u
e_1 = -1
e_2 = -1.5
r, u_1 = RK4(e_1,0)
r, u_2 = RK4(-e_2,0)
final_1 = u_1[-1]
final_2 = u_2[-1]
while abs(final_2-final_1) > 1e-8:
    eb = (e_1+e_2)/2
    r, u = RK4(eb,0)
    ub = u[-1]
    if final_1*ub > 0:
        final_1=ub
        e_1=eb
    else:
        final_2=ub
        e_2=eb

print(eb,ub)

r,u = RK4(eb,0)
I = np.trapezoid(u,dx=h)
c = np.sqrt(1/I)
u_norm = c * u

plt.plot(r,u_norm)
# Out:
# -1.0000158578880018 4.708289408366689e-09
